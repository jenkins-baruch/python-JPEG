# %%
from matplotlib import pyplot

# %%
path = "img/moto.png"

# %%
import cv2

# %%
img = cv2.imread(path)

# %%
pyplot.imshow(img)

# %%
b, g, r = cv2.split(img)

# %%
pyplot.imshow(b)

# %%
pyplot.imshow(g)

# %%
import imagetools

# %%
import numpy as np

# %%
zeros = np.zeros(b.shape, np.uint8)

# %%
import encode

# %%
b = encode.concatenate_three_colors(b, zeros, zeros)

# %%
pyplot.imshow(b)

# %%
g = encode.concatenate_three_colors(zeros, g, zeros)

# %%
pyplot.imshow(g)

# %%
img_ycbcr = imagetools.BGR_to_YCrCb(img)

# %%
y, cr, cb = cv2.split(img_ycbcr)

# %%
y = encode.concatenate_three_colors(y, zeros, zeros)

# %%
pyplot.imshow(y)

# %%
y = imagetools.YCrCb_to_BGR(y)

# %%
pyplot.imshow(y)

# %%
print("h")
# Out:
# h

# %%
cb = encode.concatenate_three_colors(zeros, zeros, cb)

# %%
cb = imagetools.YCrCb_to_BGR(cb)

# %%
pyplot.imshow(cb)

# %%
cr = encode.concatenate_three_colors(zeros, cr, zeros)

# %%
pyplot.imshow(cr)

# %%
def split_ycbcr(img):
    a, b, c = cv2.split(cv2.cvtColor(img, cv2.COLOR_BGR2YCrCb))
    zeros = np.zeros_like(a)
    pyplot.imshow(cv2.cvtColor(cv2.merge((a, zeros, zeros)), cv2.COLOR_YCrCb2BGR))
    pyplot.show()
    pyplot.imshow(cv2.cvtColor(cv2.merge((zeros, b, zeros)), cv2.COLOR_YCrCb2BGR))
    pyplot.show()
    pyplot.imshow(cv2.cvtColor(cv2.merge((zeros, zeros, c)), cv2.COLOR_YCrCb2BGR))
    pyplot.show()

# %%
split_ycbcr(cv2.imread("img/colored.bmp"))

# %%
split_ycbcr(cv2.imread("img/moto.png"))
